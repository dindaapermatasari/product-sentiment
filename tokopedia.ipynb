# %%
import re
import string
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.svm import SVC
from string import punctuation
from collections import Counter
from wordcloud import WordCloud
from nltk import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
import nltk
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to C:\Users\Dicky
# [nltk_data]    |     Zulfikar\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
df = pd.read_csv('./data/sampled_data.csv')
df.head()
# Out:
#    Unnamed: 0                                               text  rating  \
# 0        3253      thanks..... .................................       4
# 1        3559          oke barang sudah di terima dengan baik...       4
# 2        3131      brg udh dtg #pontianak dgn slmat gan, mksih..       5
# 3        3658                Cepat dan tepat! Recommended seller       5
# 4        3252  mantaf,. langsung test.. residu hilang\nkirima...       4
#
#      category                                       product_name  product_id  \
# 0  elektronik  Rexco 18 Contact Cleaner / Pembersih Komponen ...   184464874
# 1  elektronik  Alfalink EI 428 - Kamus Elektronik Electronic ...    24896339
# 2  elektronik                 Alfalink EI 212 - Kamus Elektronik    20602038
# 3  elektronik                                      TI-84 Plus CE    38187136
# 4  elektronik  Rexco 18 Contact Cleaner / Pembersih Komponen ...   184464874
#
#   sold  shop_id                                        product_url
# 0   29  2100844  https://www.tokopedia.com/miniperkakas/rexco-1...
# 1  283   588756  https://www.tokopedia.com/omegaelectronic/alfa...
# 2  383   588756  https://www.tokopedia.com/omegaelectronic/alfa...
# 3   53   844505  https://www.tokopedia.com/datasempoa/ti-84-plu...
# 4   29  2100844  https://www.tokopedia.com/miniperkakas/rexco-1...

# %%
print(df['category'].value_counts())
# Out:
# category
# elektronik     1000
# fashion        1000
# olahraga       1000
# handphone      1000
# pertukangan    1000
# Name: count, dtype: int64

# %% [markdown]
# # Pre-Processing

# %%
df = df.drop(columns=['Unnamed: 0', 'product_id', 'shop_id', 'sold', 'product_url'])
df
# Out:
#                                                    text  rating     category  \
# 0         thanks..... .................................       4   elektronik
# 1             oke barang sudah di terima dengan baik...       4   elektronik
# 2         brg udh dtg #pontianak dgn slmat gan, mksih..       5   elektronik
# 3                   Cepat dan tepat! Recommended seller       5   elektronik
# 4     mantaf,. langsung test.. residu hilang\nkirima...       4   elektronik
# ...                                                 ...     ...          ...
# 4995                  Trims gan paket telah di terima .       4  pertukangan
# 4996  terimakasih pengiriman cepat.....................       5  pertukangan
# 4997              terima kasih n maaf baru konfirmasi..       5  pertukangan
# 4998                          Terima kasih packing rapi       4  pertukangan
# 4999  mantap gan cpt bgt kmrn trf skrng sampe padaha...       5  pertukangan
#
#                                            product_name
# 0     Rexco 18 Contact Cleaner / Pembersih Komponen ...
# 1     Alfalink EI 428 - Kamus Elektronik Electronic ...
# 2                    Alfalink EI 212 - Kamus Elektronik
# 3                                         TI-84 Plus CE
# 4     Rexco 18 Contact Cleaner / Pembersih Komponen ...
# ...                                                 ...
# 4995  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...
# 4996  staples tembak HOMASTER / steples tembak / sta...
# 4997              staples tembak homaster  / staple gun
# 4998  staples tembak staple gun tacker staples jok m...
# 4999  krisbow heavy duty 3in1 staple gun / stapler m...
#
# [5000 rows x 4 columns]

# %%
slang_df = pd.read_csv("./data/slang_dict.csv", sep=';')
slang_dict = pd.Series(slang_df['baku'].values, index=slang_df['slang'].values).to_dict()

def replace_slang(text, slang_dict):
    words = word_tokenize(text)  
    new_text = ' '.join([slang_dict[word] if word in slang_dict else word for word in words])
    return new_text

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"\&\w*;", "", text)  # Menghapus HTML entities
    text = re.sub(r"@[^\s]+", "", text)  # Menghapus mention @
    text = re.sub(r"\$\w*", "", text)  # Menghapus simbol uang
    text = re.sub(r"https?:\/\/.*\/\w*", "", text)  # Menghapus URL
    text = re.sub(r"#\w*", "", text)  # Menghapus hashtag
    text = re.sub(r"\b\w{1,2}\b", "", text)  # Menghapus kata pendek
    text = re.sub(r"\s+", " ", text).strip()  # Normalisasi spasi
    text = "".join(c for c in text if c <= "\uFFFF")  # Menghapus karakter tidak valid
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"") # menghapus tab, new line, ans back slice
    text = text.encode('ascii', 'replace').decode('ascii') # menghapus non ASCII (emoticon, chinese word, .etc)
    text = re.sub(r"\d+", " ", text) # menghapus number
    text = text.translate(str.maketrans("","",string.punctuation)) # menghapus punctuation
    text = replace_slang(text, slang_dict) # Penggantian slang

    # Penghapusan stopwords
    stop_words = set(stopwords.words('indonesian'))
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    tokens = [stemmer.stem(word) for word in tokens]

    return ' '.join(tokens)

df['cleaned_text'] = df['text'].apply(preprocess_text)
data = df.drop_duplicates(subset='cleaned_text')
df
# Out:
#                                                    text  rating     category  \
# 0         thanks..... .................................       4   elektronik
# 1             oke barang sudah di terima dengan baik...       4   elektronik
# 2         brg udh dtg #pontianak dgn slmat gan, mksih..       5   elektronik
# 3                   Cepat dan tepat! Recommended seller       5   elektronik
# 4     mantaf,. langsung test.. residu hilang\nkirima...       4   elektronik
# ...                                                 ...     ...          ...
# 4947                  Trims gan paket telah di terima .       4  pertukangan
# 4948  terimakasih pengiriman cepat.....................       5  pertukangan
# 4949              terima kasih n maaf baru konfirmasi..       5  pertukangan
# 4950                          Terima kasih packing rapi       4  pertukangan
# 4951  mantap gan cpt bgt kmrn trf skrng sampe padaha...       5  pertukangan
#
#                                            product_name  \
# 0     Rexco 18 Contact Cleaner / Pembersih Komponen ...
# 1     Alfalink EI 428 - Kamus Elektronik Electronic ...
# 2                    Alfalink EI 212 - Kamus Elektronik
# 3                                         TI-84 Plus CE
# 4     Rexco 18 Contact Cleaner / Pembersih Komponen ...
# ...                                                 ...
# 4947  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...
# 4948  staples tembak HOMASTER / steples tembak / sta...
# 4949              staples tembak homaster  / staple gun
# 4950  staples tembak staple gun tacker staples jok m...
# 4951  krisbow heavy duty 3in1 staple gun / stapler m...
#
#                                            cleaned_text     label
# 0                                                thanks  positive
# 1                                     oke barang terima  positive
# 2                     bareng selamat kawan terima kasih  positive
# 3                              cepat rekomendasi seller  positive
# 4     mantap langsung test residu hilang kirim lamba...  negative
# ...                                                 ...       ...
# 4947                    terima kasih kawan paket terima  positive
# 4948              terimakasih kirim cepat barang sesuai  positive
# 4949                       terima kasih maaf konfirmasi  positive
# 4950                          terima kasih packing rapi  positive
# 4951  mantap kawan cepat banget kemarin transfer pak...  positive
#
# [4952 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4951 entries, 0 to 4951
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          4951 non-null   object
#  1   rating        4951 non-null   int64
#  2   category      4951 non-null   object
#  3   product_name  4951 non-null   object
#  4   cleaned_text  4951 non-null   object
#  5   label         4951 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 270.8+ KB

# %%
# Cek baris yang memiliki NaN di cleaned_text
nan_rows = df[df['cleaned_text'].isna()]
print(nan_rows[['text', 'cleaned_text']])
# Out:
# Empty DataFrame
# Columns: [text, cleaned_text]
# Index: []

# %%
df = df.dropna(subset=['cleaned_text'])
df.isnull().sum()
# Out:
# text            0
# rating          0
# category        0
# product_name    0
# cleaned_text    0
# label           0
# dtype: int64

# %% [markdown]
# # Klasifikasi Sentimen

# %% [markdown]
# Pelabelan Manual

# %%
positive_words = ["gak kecewa", "super", "sip", "cepat", "suka", "mantab", "worth", "awet", "mantul", "selamat", "good", "recomended", "tebal", "semangat", "rekomendasi", "kuat", "thank you", "makasih", "aman", "rapi", "fast", "thanks", "barang", "sesuai", "cepae", "bagus", "selamat", "sudah", "sampai", "terima", "excellent", "baik", "mantap", "puas", "terima kasih", "keren" "original", "percaya", "awesomee", "terimakasih", "thank you", "murah", "recommended", "aman", "pas", "bersih", "original", "rapi", "mulus", "sukses", "ramah", "cocok", "nyaman", "terpercaya", "top", "sip", "oke"]
negative_words = ["gagal", "cacat", "tidak", "kurang", "rusak", "salah", "lama", "terlambat", "jelek", "cacat", "kecewa", "penipuan", "palsu", "buruk", "lelet", "kotor", "hancur", "lambat", "menyesal", "tidak sesuai", "bohong", "residu", "disayangkan", "trouble", "mengecewakan"]

def label_sentiment(text):
    if isinstance(text, str):
        pos_count = sum(1 for word in positive_words if word in text)
        neg_count = sum(1 for word in negative_words if word in text)
        
        if pos_count > neg_count:
            return 'positive'
        elif neg_count > pos_count:
            return 'negative'
        else:
            return 'neutral'
    else:
        return 'neutral'  

df['label'] = df['cleaned_text'].apply(label_sentiment)
df.sample(5)
# Out:
#                                                    text  rating     category  \
# 4591                      Nuhun barangsudah kami terima       5  pertukangan
# 2926  top,pngriman cepat. brg sangat memuaskan. trim...       5     olahraga
# 4178                    Kualitas n harga OK. Recommend!       5  pertukangan
# 2653  Fast respon..harga oke bgt. Maju terus lapakny...       4     olahraga
# 3924     fast respone, barang berfungsi dengan sempurna       4    handphone
#
#                                            product_name  \
# 4591  Staples Gun Tacker Mollar 3 in 1 / Staple Jok ...
# 2926                                Bola Basket Proteam
# 4178              staples tembak homaster  / staple gun
# 2653   Decker / Dekker / Deker Bahu / Shoulder Athelete
# 3924  Speaker Bluetooth Football &#40;MINI&#41; / Sp...
#
#                                       cleaned_text     label
# 4591                      nuhun barangsudah terima  positive
# 2926      toppngriman cepat bareng muas trimaksihh  positive
# 4178                    kualitas harga rekomendasi  positive
# 2653  fast responharga oke banget maju lapak kawan  positive
# 3924           fast respone barang fungsi sempurna  positive

# %%
sentiment_counts = df['label'].value_counts()
print(sentiment_counts)
# Out:
# label
# positive    4448
# neutral      458
# negative      45
# Name: count, dtype: int64

# %% [markdown]
# Menyimpan Data

# %%
df.to_excel('data_cleaned.xlsx', index=False)

# %% [markdown]
# Membaca Data Hasil Pre-Processing

# %%
df = pd.read_excel('data_cleaned.xlsx')

# %% [markdown]
# Memisahkan Fitur dan Target

# %%
X = df['cleaned_text'] 
y = df['label']

# %% [markdown]
# TF-IDF Vectorization

# %%
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(X)

# %% [markdown]
# Split Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Pemodelan

# %% [markdown]
# Model Naive Bayes

# %%
model_nb = MultinomialNB()
model_nb.fit(X_train, y_train)
y_pred_nb = model_nb.predict(X_test)

print('--------------------- Confusion Matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_nb))

print('--------------------- Classification Report  ----------------------------')
print(classification_report(y_test, y_pred_nb))
# Out:
# --------------------- Confusion Matrix  ----------------------------
# [[  0   0   9]
#  [  0   4  88]
#  [  0   0 890]]
# --------------------- Classification Report  ----------------------------
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         9
#      neutral       1.00      0.04      0.08        92
#     positive       0.90      1.00      0.95       890
#
#     accuracy                           0.90       991
#    macro avg       0.63      0.35      0.34       991
# weighted avg       0.90      0.90      0.86       991
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Model Support Vector Machine (SVM)

# %%
model_svm = svm.SVC(kernel='linear')
model_svm.fit(X_train, y_train)
y_pred_svm = model_svm.predict(X_test)

print('--------------------- Confusion Matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_svm))

print('--------------------- Classification Report  ----------------------------')
print(classification_report(y_test, y_pred_svm))
# Out:
# --------------------- Confusion Matrix  ----------------------------
# [[  0   7   2]
#  [  0  28  64]
#  [  0   2 888]]
# --------------------- Classification Report  ----------------------------
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         9
#      neutral       0.76      0.30      0.43        92
#     positive       0.93      1.00      0.96       890
#
#     accuracy                           0.92       991
#    macro avg       0.56      0.43      0.47       991
# weighted avg       0.91      0.92      0.91       991
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Model Random Forest

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

print('--------------------- Confusion Matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_rf))

print('--------------------- Classification Report  ----------------------------')
print(classification_report(y_test, y_pred_rf))
# Out:
# --------------------- Confusion Matrix  ----------------------------
# [[  2   4   3]
#  [  0  19  73]
#  [  1   4 885]]
# --------------------- Classification Report  ----------------------------
#               precision    recall  f1-score   support
#
#     negative       0.67      0.22      0.33         9
#      neutral       0.70      0.21      0.32        92
#     positive       0.92      0.99      0.96       890
#
#     accuracy                           0.91       991
#    macro avg       0.76      0.47      0.54       991
# weighted avg       0.90      0.91      0.89       991

# %% [markdown]
# Model Regresi Logistik

# %%
model_logistic = LogisticRegression(random_state=42)
model_logistic.fit(X_train, y_train)
y_pred_logistic = model_logistic.predict(X_test)

print('--------------------- Confusion Matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_logistic))

print('--------------------- Classification Report  ----------------------------')
print(classification_report(y_test, y_pred_logistic))
# Out:
# --------------------- Confusion Matrix  ----------------------------
# [[  0   5   4]
#  [  0  17  75]
#  [  0   1 889]]
# --------------------- Classification Report  ----------------------------
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         9
#      neutral       0.74      0.18      0.30        92
#     positive       0.92      1.00      0.96       890
#
#     accuracy                           0.91       991
#    macro avg       0.55      0.39      0.42       991
# weighted avg       0.89      0.91      0.89       991
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Dicky Zulfikar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Model Decision Tree

# %%
model_tree = DecisionTreeClassifier(random_state=42)
model_tree.fit(X_train, y_train)
y_pred_tree = model_tree.predict(X_test)

print('--------------------- Confusion Matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_tree))

print('--------------------- Classification Report  ----------------------------')
print(classification_report(y_test, y_pred_tree))
# Out:
# --------------------- Confusion Matrix  ----------------------------
# [[  7   2   0]
#  [  0  86   6]
#  [  1  40 849]]
# --------------------- Classification Report  ----------------------------
#               precision    recall  f1-score   support
#
#     negative       0.88      0.78      0.82         9
#      neutral       0.67      0.93      0.78        92
#     positive       0.99      0.95      0.97       890
#
#     accuracy                           0.95       991
#    macro avg       0.85      0.89      0.86       991
# weighted avg       0.96      0.95      0.95       991

# %% [markdown]
# Validasi Silang (Cross-Validation)

# %%
models = {
    "Naive Bayes": MultinomialNB(),
    "SVM": SVC(),
    "Logistic Regression": LogisticRegression(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
}

for name, model in models.items():
    score = cross_val_score(model, X_tfidf, y, cv=5, scoring='accuracy')  
    print(f"{name} Cross-validation scores: {score}")
    print(f"{name} Mean Cross-validation score: {score.mean():.4f}\n")
# Out:
# Naive Bayes Cross-validation scores: [0.90413724 0.9030303  0.9020202  0.9        0.9030303 ]
# Naive Bayes Mean Cross-validation score: 0.9024
#
# SVM Cross-validation scores: [0.9061554  0.90909091 0.90606061 0.9010101  0.91111111]
# SVM Mean Cross-validation score: 0.9067
#
# Logistic Regression Cross-validation scores: [0.91019173 0.91616162 0.91111111 0.91212121 0.91414141]
# Logistic Regression Mean Cross-validation score: 0.9127
#
# Random Forest Cross-validation scores: [0.91826438 0.91818182 0.90505051 0.92020202 0.91818182]
# Random Forest Mean Cross-validation score: 0.9160
#
# Decision Tree Cross-validation scores: [0.95862765 0.93030303 0.92525253 0.94848485 0.95151515]
# Decision Tree Mean Cross-validation score: 0.9428

# %% [markdown]
# Memisahkan Review Positif dan Negatif

# %%
positive = df[df['label'] == 'positive']
negative = df[df['label'] == 'negative']
neutral = df[df['label'] == 'neutral']

# %% [markdown]
# Menggabungkan Teks Review Positif dan Negatif

# %%
positive_text = ' '.join(positive['cleaned_text'])
negative_text = ' '.join(negative['cleaned_text'])
neutral_text = ' '.join(neutral['cleaned_text'])

# %%
positive_reviews = pd.DataFrame({'Review': positive['cleaned_text'], 'Sentiment': 'Positive'})
negative_reviews = pd.DataFrame({'Review': negative['cleaned_text'], 'Sentiment': 'Negative'})
neutral_reviews = pd.DataFrame({'Review': neutral['cleaned_text'], 'Sentiment': 'Neutral'})

# %%
positive_reviews
# Out:
#                                                  Review Sentiment
# 0                                                thanks  Positive
# 1                                     oke barang terima  Positive
# 2                     bareng selamat kawan terima kasih  Positive
# 3                              cepat rekomendasi seller  Positive
# 5                             barang cepat paking bagus  Positive
# ...                                                 ...       ...
# 4946                    terima kasih kawan paket terima  Positive
# 4947              terimakasih kirim cepat barang sesuai  Positive
# 4948                       terima kasih maaf konfirmasi  Positive
# 4949                          terima kasih packing rapi  Positive
# 4950  mantap kawan cepat banget kemarin transfer pak...  Positive
#
# [4448 rows x 2 columns]

# %%
neutral_reviews
# Out:
#                                                  Review Sentiment
# 13    bagus produk sayang system kirim send trouble ...   Neutral
# 15                                alfalinknya kecilimut   Neutral
# 22                                          danke kawan   Neutral
# 26    ya harga ribu lumayan laah jangkau mudah an aweet   Neutral
# 35                                  biar bintang bicara   Neutral
# ...                                                 ...       ...
# 4869                               okkkkkkkkkkkkkkkkkkk   Neutral
# 4888                        jam transaksiudah rumahmksh   Neutral
# 4896                           biar bintang bicarathank   Neutral
# 4898                                   masang jok pakai   Neutral
# 4943                                             mkasih   Neutral
#
# [458 rows x 2 columns]

# %%
negative_reviews.sample(10)
# Out:
#                                                  Review Sentiment
# 2853                 salah warna konfirmasi warna pesan  Negative
# 2521     bahan material besi cat kualitas produk kecewa  Negative
# 1153                                 kecewa inti kecewa  Negative
# 1811            sepatu bagus cacat ukur sesak ukur kaki  Negative
# 130                                        tombol rusak  Negative
# 1549  mengecwakan pesan sepatu kirim sepatu dintelfo...  Negative
# 1799  sesuai expektasi cacat konektor milik tiang im...  Negative
# 3057                                        layan buruk  Negative
# 1087                      kotak rusak lem sepatu banget  Negative
# 4236                            salah beli mollar pakai  Negative

# %%
sentiment_counts = df['label'].value_counts()
sentiment_counts.plot(kind='bar', color=['green', 'yellow', 'red'])
plt.title('Jumlah Review Positif dan Negatif')
plt.xlabel('label')
plt.ylabel('Jumlah Review')
plt.xticks(rotation=0)
plt.show()

# %%
# Word Cloud untuk review positif
wordcloud_pos = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Review Positif')
plt.show()

# %%
# Word Cloud untuk review negatif
wordcloud_neg = WordCloud(width=800, height=400, background_color='white').generate(negative_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Review Negatif')
plt.show()

# %% [markdown]
# Menampilkan Kata Paling Umum

# %%
def tokenize_text(text):
    return word_tokenize(text)
 
df['tokenized_text'] = df['cleaned_text'].apply(tokenize_text)
all_tokens = [token for sublist in df['tokenized_text'] for token in sublist]

fqdist = FreqDist(all_tokens)
most_common_words = fqdist.most_common(15)
most_common_words
# Out:
# [('barang', 2215),
#  ('sesuai', 1455),
#  ('terima', 1190),
#  ('cepat', 1110),
#  ('bagus', 923),
#  ('kasih', 728),
#  ('kirim', 699),
#  ('kawan', 461),
#  ('pesan', 449),
#  ('mantap', 446),
#  ('respon', 434),
#  ('thanks', 384),
#  ('produk', 364),
#  ('seller', 362),
#  ('deskripsi', 314)]

# %%
words = [word for word, freq in most_common_words]
frequencies = [freq for word, freq in most_common_words]

plt.figure(figsize=(10, 6))
sns.barplot(x=frequencies, y=words, palette="viridis")

plt.title("15 Most Common Words")
plt.xlabel("Frekuensi")
plt.ylabel("Words")
plt.show()
# Out:
# C:\Users\Dicky Zulfikar\AppData\Local\Temp\ipykernel_17536\803265152.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies, y=words, palette="viridis")

# %% [markdown]
# Menampilkan Frekuensi Kata Per Kategori

# %%
pemetaan_kata = {
    'Kualitas': ['bagus', 'mantap', 'sesuai', 'kualitas'],
    'Pengiriman': ['cepat', 'kirim', 'terima', 'lama'],
    'Seller/Respon': ['respon', 'seller', 'toko', 'ramah'],
    'Kesesuaian Produk': ['produk', 'sesuai', 'ukuran', 'pas'],
    'Deskripsi': ['deskripsi']
}

def get_word_frequencies(text_series):
    word_list = []
    for review in text_series:
        words = re.findall(r'\b\w+\b', review.lower())  
        word_list.extend(words)
    word_frequencies = Counter(word_list)
    return word_frequencies

categories = df['category'].unique() 
pemetaan_hasil = {kategori: {} for kategori in categories}

for category in categories:
    category_data = df[df['category'] == category] 
    frequencies = get_word_frequencies(category_data['cleaned_text'])
    
    for kata, freq in frequencies.most_common(15):
        for kategori, kata_kategori in pemetaan_kata.items():
            if kata in kata_kategori:
                if kategori not in pemetaan_hasil[category]:
                    pemetaan_hasil[category][kategori] = []
                pemetaan_hasil[category][kategori].append((kata, freq))

print("\nPemetaan Kata Berdasarkan Kategori:")
for category, kata_map in pemetaan_hasil.items():
    print(f"\n{category}:")
    for kategori, kata_freq in kata_map.items():
        print(f"  {kategori}: {', '.join(f'{kata} ({freq})' for kata, freq in kata_freq)}")
# Out:
# Pemetaan Kata Berdasarkan Kategori:
#
# elektronik:
#   Pengiriman: terima (270), cepat (268), kirim (160)
#   Kualitas: sesuai (242), bagus (174), mantap (103)
#   Kesesuaian Produk: sesuai (242), produk (69)
#   Seller/Respon: respon (107), seller (92)
#
# fashion:
#   Kualitas: sesuai (367), bagus (235)
#   Kesesuaian Produk: sesuai (367), produk (107)
#   Pengiriman: cepat (257), kirim (163), terima (162)
#   Seller/Respon: respon (101)
#
# olahraga:
#   Kualitas: sesuai (285), bagus (196), mantap (99), kualitas (79)
#   Kesesuaian Produk: sesuai (285), produk (56)
#   Pengiriman: terima (281), cepat (196), kirim (104)
#   Seller/Respon: respon (68), seller (61)
#
# handphone:
#   Kualitas: sesuai (271), bagus (156), mantap (84)
#   Kesesuaian Produk: sesuai (271), produk (69)
#   Pengiriman: terima (191), cepat (163), kirim (141)
#   Seller/Respon: respon (70)
#
# pertukangan:
#   Kualitas: sesuai (290), bagus (162), mantap (92)
#   Kesesuaian Produk: sesuai (290), produk (63)
#   Pengiriman: terima (286), cepat (226), kirim (131)
#   Seller/Respon: respon (88), seller (82)
#   Deskripsi: deskripsi (76)

# %% [markdown]
# Melakukan Ringkasan dari Pemetaan

# %%
def ringkasan_kategori(pemetaan_hasil):
    ringkasan = {}
    
    for category, kata_map in pemetaan_hasil.items():
        kualitas = set()
        pengiriman = set()
        seller = set()
        deskripsi = set()
        kesesuaian_produk = set() 
        
        if 'Kualitas' in kata_map:
            for kata, freq in kata_map['Kualitas']:
                kualitas.add(kata)
        if 'Pengiriman' in kata_map:
            pengiriman_list = [kata for kata, freq in kata_map['Pengiriman']]
            if 'cepat' in pengiriman_list:
                pengiriman = {'cepat'}
            else:
                pengiriman = set(pengiriman_list)
        if 'Seller/Respon' in kata_map:
            for kata, freq in kata_map['Seller/Respon']:
                seller.add(kata)
        if 'Deskripsi' in kata_map:
            deskripsi.add('Produk sesuai dengan deskripsi')
        if 'Kesesuaian Produk' in kata_map:
            kesesuaian_produk.add('Kesesuaian produk sesuai')
        
        kalimat_kualitas = f"Kualitas produk {category} " + ', '.join(kualitas) + "."
        kalimat_pengiriman = " Pengiriman " + ', '.join(pengiriman) + "."
        kalimat_seller = " Seller memberikan fast respon." if seller else ""
        kalimat_deskripsi = " " + ', '.join(deskripsi) + "." if deskripsi else ""
        kalimat_kesesuaian_produk = " " + ', '.join(kesesuaian_produk) + "." if kesesuaian_produk else ""

        ringkasan[category] = (
            kalimat_kualitas +
            kalimat_pengiriman +
            kalimat_seller +
            kalimat_deskripsi +
            kalimat_kesesuaian_produk
        )
    
    return ringkasan

ringkasan_hasil_singkat = ringkasan_kategori(pemetaan_hasil)
df_ringkasan_singkat = pd.DataFrame(list(ringkasan_hasil_singkat.items()), columns=['Kategori', 'Ringkasan'])
print(df_ringkasan_singkat.to_string(index=False))
# Out:
#    Kategori                                                                                                                                                     Ringkasan
#  elektronik                                  Kualitas produk elektronik sesuai, bagus, mantap. Pengiriman cepat. Seller memberikan fast respon. Kesesuaian produk sesuai.
#     fashion                                             Kualitas produk fashion sesuai, bagus. Pengiriman cepat. Seller memberikan fast respon. Kesesuaian produk sesuai.
#    olahraga                          Kualitas produk olahraga sesuai, kualitas, bagus, mantap. Pengiriman cepat. Seller memberikan fast respon. Kesesuaian produk sesuai.
#   handphone                                   Kualitas produk handphone sesuai, bagus, mantap. Pengiriman cepat. Seller memberikan fast respon. Kesesuaian produk sesuai.
# pertukangan Kualitas produk pertukangan sesuai, bagus, mantap. Pengiriman cepat. Seller memberikan fast respon. Produk sesuai dengan deskripsi. Kesesuaian produk sesuai.
